# %% [markdown]
# API (Application Programming Interface)
# Websites provide data in the form of APIs
# Developers send requests to the API and it sends the response back.

# %%
import requests
URL = 'api url'
res = requests.URL
json_data_res = res.json()
df = pd.json_normalize(json_data_res(['data']))
